# %% [markdown]
# Load the Dataset

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5db1bb3-b5c0-4b27-95db-381b178a30f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5db1bb3-b5c0-4b27-95db-381b178a30f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
data = io.BytesIO(uploaded['who_data.csv'])

# %%
# Read the data
who_df = pd.read_csv("who_data.csv")

# %% [markdown]
# Data Exploration

# %%
who_df.shape
# Out:
# (32561, 15)

# %%
# Randomly check  10 rows of the dataset
who_df.sample(10)
# Out:
#        age          workclass  fnlwgt   education  education_no_of_years  \
# 11901   40            Private  214242     HS-grad                      9
# 29599   42        Federal-gov  557644     HS-grad                      9
# 21040   30            Private  159187   Bachelors                     13
# 2579    47            Private  188330     HS-grad                      9
# 30670   50            Private  205100     7th-8th                      4
# 10351   44            Private  201924   Bachelors                     13
# 26908   30            Private  169583     HS-grad                      9
# 19777   36            Private   86459   Assoc-voc                     11
# 31104   47          Local-gov  200471     HS-grad                      9
# 16705   59   Self-emp-not-inc  199240     HS-grad                      9
#
#             marital_status          occupation    relationship    race  \
# 11901   Married-civ-spouse   Machine-op-inspct         Husband   White
# ...

# %%
# check the data types
who_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32561 non-null  int64
#  1   workclass               32561 non-null  object
#  2   fnlwgt                  32561 non-null  int64
#  3   education               32561 non-null  object
#  4   education_no_of_years   32561 non-null  int64
#  5   marital_status          32561 non-null  object
#  6   occupation              32561 non-null  object
#  7   relationship            32561 non-null  object
#  8   race                    32561 non-null  object
#  9   sex                     32561 non-null  object
#  10  capital_gain            32561 non-null  int64
#  11  capital_loss            32561 non-null  int64
#  12  working_hours_per_week  32561 non-null  int64
#  13  native_country          32561 non-null  object
# ...

# %%
# Check some statistics of the dataset
who_df.describe(include= "all")
# Out:
#                  age workclass        fnlwgt education  education_no_of_years  \
# count   32561.000000     32561  3.256100e+04     32561           32561.000000
# unique           NaN         9           NaN        16                    NaN
# top              NaN   Private           NaN   HS-grad                    NaN
# freq             NaN     22696           NaN     10501                    NaN
# mean       38.581647       NaN  1.897784e+05       NaN              10.080679
# std        13.640433       NaN  1.055500e+05       NaN               2.572720
# min        17.000000       NaN  1.228500e+04       NaN               1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN               9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN              10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN              12.000000
# max        90.000000       NaN  1.484705e+06       NaN              16.000000
#
# ...

# %%
# Descriptive statistics on numeric data
who_df.describe()
# Out:
#                 age        fnlwgt  education_no_of_years  capital_gain  \
# count  32561.000000  3.256100e+04           32561.000000  32561.000000
# mean      38.581647  1.897784e+05              10.080679   1077.648844
# std       13.640433  1.055500e+05               2.572720   7385.292085
# min       17.000000  1.228500e+04               1.000000      0.000000
# 25%       28.000000  1.178270e+05               9.000000      0.000000
# 50%       37.000000  1.783560e+05              10.000000      0.000000
# 75%       48.000000  2.370510e+05              12.000000      0.000000
# max       90.000000  1.484705e+06              16.000000  99999.000000
#
#        capital_loss  working_hours_per_week
# count  32561.000000            32561.000000
# mean      87.303830               40.437456
# std      402.960219               12.347429
# min        0.000000                1.000000
# 25%        0.000000               40.000000
# 50%        0.000000               40.000000
# ...

# %% [markdown]
# The maximun age is 90years, minimum age is 17 years while average age is 38 years.
# The maximum hours worked per week is 99 hours, minimum is 1 hour while the average hours of work per week is about 40 hours.
# The maximum years of education is 16, minimum is 1 year while the average is about 10 years.

# %%
# Categorical data descriptive statistics
cat_who_df = who_df.select_dtypes(include = "object")
cat_who_df.describe()
# Out:
#        workclass education       marital_status       occupation relationship  \
# count      32561     32561                32561            32561        32561
# unique         9        16                    7               15            6
# top      Private   HS-grad   Married-civ-spouse   Prof-specialty      Husband
# freq       22696     10501                14976             4140        13193
#
#           race    sex  native_country  salary
# count    32561  32561           32561   32561
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     27816  21790           29170   24720

# %%
# Check all categories with their counts
for col in cat_who_df:
  print(who_df[col].value_counts())
  print("-"*50)
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
# --------------------------------------------------
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
# --------------------------------------------------
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
# ...

# %%
# Check for missing values
who_df.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# education                 0
# education_no_of_years     0
# marital_status            0
# occupation                0
# relationship              0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# working_hours_per_week    0
# native_country            0
# salary                    0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset

# %%
# Check for duplicated rows
who_df.duplicated().sum()
# Out:
# 24

# %% [markdown]
# There are 24 rows with exactly the same information (duplicated), which will be removed

# %%
# Remove duplicated rows
who_df = who_df.drop_duplicates()

# Reset Index
who_df = who_df.reset_index(drop = True)

# %%
# Sanity Check on duplicate rows
who_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data Visualization

# %% [markdown]
# Univariate Analysis (Numerical Features)

# %%
def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
histogram_boxplot(data = who_df, feature = "age")

# %%
histogram_boxplot(data = who_df, feature = "fnlwgt")

# %%
histogram_boxplot(data = who_df, feature = "education_no_of_years")

# %%
histogram_boxplot(data = who_df, feature = "capital_gain")

# %%
histogram_boxplot(data = who_df, feature = "capital_loss")

# %%
histogram_boxplot(data = who_df, feature = "working_hours_per_week")

# %% [markdown]
# Univariate Analysis (Categorical Features)

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None, title = None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """
    
    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage
    plt.title(title)
    plt.show()  # show the plot

# %%
labeled_barplot(data = who_df, feature = "workclass", perc = True, title = "Distribution of Workclass")

# %%
labeled_barplot(data = who_df, feature = "education", perc = True, title = "Distribution of Education Level")

# %%
labeled_barplot(data = who_df, feature = "marital_status", perc = True, title = "Distribution of Marital Status")

# %%
labeled_barplot(data = who_df, feature = "occupation", perc = True, title = "Distribution of Occupation")

# %% [markdown]
# The top 5 occupations are Prof-speciality, Craft-repair, Executive managerial,Admin clerical and Sales.

# %%
labeled_barplot(data = who_df, feature = "relationship", perc = True, title = "Distribution of Relationship")

# %% [markdown]
# Most of the people are Husband at 40.5% of the dataset, 25.5% are Not-in-family while 15.6% of the dataset are Own-child

# %%
labeled_barplot(data = who_df, feature = "race", perc = True, title = "Distribution of Race")

# %% [markdown]
# Majority of the people in this dataset are of the white race accounting for about 85%, followed by black race of 9.6% and Asian Pacific Islander at 3.2%

# %%
labeled_barplot(data = who_df, feature = "sex", perc = True, title = "Distribution of Sex")

# %% [markdown]
# About 67% of the people are male

# %%
labeled_barplot(data = who_df, feature = "native_country", perc = True, title = "Distribution of Country")

# %% [markdown]
# Majority of the people are a native of United Stated which account for almost 90% of the dataset

# %%
labeled_barplot(data = who_df, feature = "salary", perc = True, title = "Distribution of Salary")

# %% [markdown]
# Bivariate Analysis (Numerical Features)

# %%
num_data = who_df.select_dtypes(include = "number")

# %%
mat_cor = num_data.corr()

plt.figure(figsize = (8, 5))
sns.heatmap(mat_cor, annot = True, vmin = -1, vmax = 1, cmap = "Spectral")
plt.title("Heatmap showing correlation of features with target");

# %% [markdown]
# There is no high correlation between numeric variables. No multicollinearity

# %%
# Function to create scatterplot between two numerical features
def custom_scatterplot(x, y, title, data = who_df):
  plt.figure(figsize = (6, 4))
  sns.scatterplot(x = x, y = y, data = who_df)
  plt.title(title)
  plt.show()

# %%
custom_scatterplot(data = who_df, x = "age", y = "education_no_of_years", title = "Distribution of Age vs Years of Education")

# %%
custom_scatterplot(data = who_df, x = "age", y = "working_hours_per_week", title = "Distribution of Age vs Working hours per week")

# %%
custom_scatterplot(data = who_df, x = "age", y = "capital_gain", title = "Distribution of Age vs Capital Gain")

# %%
custom_scatterplot(data = who_df, x = "age", y = "capital_loss", title = "Distribution of Age vs Capital Loss")

# %%
custom_scatterplot(data = who_df, x = "age", y = "fnlwgt", title = "Distribution of Age vs CPS Weight")

# %%
custom_scatterplot(data = who_df, x = "education_no_of_years", y = "working_hours_per_week", title = "Distribution of Education Years vs Working hours per week")

# %%
custom_scatterplot(data = who_df, x = "education_no_of_years", y = "capital_gain", title = "Distribution of Education Years vs Capital Gain")

# %%
custom_scatterplot(data = who_df, x = "education_no_of_years", y = "capital_loss", title = "Distribution of Education Years vs Capital Loss")

# %%
custom_scatterplot(data = who_df, x = "working_hours_per_week", y = "capital_gain", title = "Distribution of Working hours per week vs Capital Gain")

# %%
custom_scatterplot(data = who_df, x = "working_hours_per_week", y = "capital_loss", title = "Distribution of Working hours per week vs Capital Loss")

# %% [markdown]
# Bivariate Analysis (Numerical/Categorical Features)

# %%
# Function to create boxplot between numerical and categorical features
def custom_boxplot(x, y, title, data = who_df):
  plt.figure(figsize = (6, 4))
  sns.boxplot(x = x, y = y, data = who_df)
  plt.title(title)
  plt.show()

# %%
custom_boxplot(x = 'salary', y="age", data = who_df, title = "Distribution of Salary vs Age")

# %% [markdown]
# On the average, older people earn more, above 50,000

# %%
custom_boxplot(x = 'salary', y="fnlwgt", data = who_df, title = "Distribution of Salary vs CPS Weight")

# %% [markdown]
# CPS weight does not have an impact on the Salary earned

# %%
custom_boxplot(x = 'salary', y="education_no_of_years", data = who_df, title = "Distribution of Salary vs Education Years")

# %% [markdown]
# On the average, people with more Education years earn more income, above 50,000

# %%
custom_boxplot(x = 'salary', y="capital_gain", data = who_df, title = "Distribution of Salary vs Capital Gain")

# %% [markdown]
# Capital Gain does not influence the income earned

# %%
custom_boxplot(x = 'salary', y="capital_loss", data = who_df, title = "Distribution of Salary vs Capital Loss")

# %% [markdown]
# Capital Loss does not influence the income earned

# %%
custom_boxplot(x = 'salary', y="working_hours_per_week", data = who_df, title = "Distribution of Salary vs Working Hours per week")

# %% [markdown]
# People that work more hours earn more

# %% [markdown]
# ### **Outlier detection and treatment**

# %%
# outlier detection using boxplot

plt.figure(figsize = (20, 30))
    
for i, variable in enumerate(num_data):
  plt.subplot(5, 4, i + 1)
  plt.boxplot(who_df[variable])
  plt.title(variable)

plt.show()

# %%
l1 = [-200, 5, 0, 1000]

np.clip(l1, 0, 5)
# Out:
# array([0, 5, 0, 5])

# %%
def treat_outliers(df, col):
  """
  treat outliers in variable
  col: str, name of the numerical variable
  df: dataframe
  """
  Q1 = df[col].quantile(0.25)  # 25th quantile
  Q3 = df[col].quantile(0.75) # upper quantile
  IQR = Q3 - Q1
  lower_whisker = Q1 - (1.5 * IQR)
  upper_whisker = Q3 + (1.5 * IQR)
  df[col] = np.clip(df[col], lower_whisker, upper_whisker)
  return df

def treat_outliers_all(df, col_list):
  for c in col_list:
    df = treat_outliers(df, c)
  return df

# %%
who_df = treat_outliers_all(who_df, num_data)

# %%
# Sanity check on outlier treatment

plt.figure(figsize = (20, 30))

for i, variable in enumerate(num_data):
  plt.subplot(5, 4, i + 1)
  plt.boxplot(who_df[variable], whis=1.5)
  plt.title(variable)

plt.show()

# %%
labeled_barplot(data = who_df, feature = "salary", perc = True, title = "Distribution of Salary")

# %%
who_df['salary'].value_counts(normalize = True)
# Out:
#  <=50K    0.759074
#  >50K     0.240926
# Name: salary, dtype: float64

# %% [markdown]
# **Spit the Data**

# %%
from sklearn.model_selection import train_test_split

# Select the features

X = who_df.drop("salary", axis = 1)
y = who_df["salary"]

# %%
# convert all categorical features to numerical data: OneHotEncoding

X = pd.get_dummies(X, drop_first = True)

X.head()
# Out:
#    age  fnlwgt  education_no_of_years  capital_gain  capital_loss  \
# 0   39   77516                   13.0             0             0
# 1   50   83311                   13.0             0             0
# 2   38  215646                    9.0             0             0
# 3   53  234721                    7.0             0             0
# 4   28  338409                   13.0             0             0
#
#    working_hours_per_week  workclass_ Federal-gov  workclass_ Local-gov  \
# 0                    40.0                       0                     0
# 1                    32.5                       0                     0
# 2                    40.0                       0                     0
# 3                    40.0                       0                     0
# 4                    40.0                       0                     0
#
#    workclass_ Never-worked  workclass_ Private  ...  native_country_ Portugal  \
# ...

# %%
# encoding the target
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

y_new = le.fit_transform(y)

# %%
# Check
from collections import Counter
Counter(y_new)
# Out:
# Counter({0: 24698, 1: 7839})

# %%
# Split the data into training, validation and testing

x_temp, x_test, y_temp, y_test = train_test_split(X, y_new, test_size = 0.2, random_state = 0, stratify = y)
x_train, x_val, y_train, y_val = train_test_split(x_temp, y_temp, test_size = 0.2, random_state = 0)


#x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %% [markdown]
# **Check split data**

# %%
x_train.shape
# Out:
# (20823, 100)

# %%
x_val.shape
# Out:
# (5206, 100)

# %%
x_test.shape
# Out:
# (6508, 100)

# %% [markdown]
# ### **Data Prepreparation**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Normalize the data using MinMaxScaler

scaler = MinMaxScaler()

x_train_sd = scaler.fit_transform(x_train)
x_val_sd = scaler.transform(x_val)
x_test_sd = scaler.transform(x_test)

# %% [markdown]
# ### **Model building - Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(random_state = 0, class_weight ={1:0.9, 0:0.1}, max_iter=1000)

log_reg.fit(x_train_sd, y_train)
# Out:
# LogisticRegression(class_weight={0: 0.1, 1: 0.9}, max_iter=1000, random_state=0)

# %%
# Check Accuracy score on train dataset

log_reg.score(x_train_sd, y_train)
# Out:
# 0.6908706718532392

# %%
# Check Accuracy score on train dataset

log_reg.score(x_val_sd, y_val)
# Out:
# 0.6928543987706492

# %%
# Check Probability score on test dataset

log_reg.predict_proba(x_test_sd)
# Out:
# array([[0.59816266, 0.40183734],
#        [0.05555741, 0.94444259],
#        [0.34716505, 0.65283495],
#        ...,
#        [0.27490622, 0.72509378],
#        [0.51876369, 0.48123631],
#        [0.99616357, 0.00383643]])

# %% [markdown]
# ### **Model Performance Check**

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

# %% [markdown]
# #### **Confusion Matrix**

# %%
# function to compute different metrics to check performance of a regression model
def model_performance_classification(model, predictors, target, threshold = 0.5):
    """
    Function to compute different metrics to check regression model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred_proba = model.predict_proba(predictors)[:, 1]
    # convert the probability to class
    pred_class = np.round(pred_proba > threshold)
    acc = accuracy_score(target, pred_class)  # to compute acuracy
    recall = recall_score(target, pred_class, average = "weighted")  # to compute recall
    precision = precision_score(target, pred_class, average="weighted")  # to compute precision
    f1 = f1_score(target, pred_class, average="weighted")  # to compute F1 score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1-score": f1
        },
        index=[0])
    conf = confusion_matrix(target, pred_class)
    plt.figure(figsize=(8, 5))
    sns.heatmap(conf, annot=True, fmt="g")
    plt.xlabel("Predicted label")
    plt.ylabel("Actual label")
    plt.show()
 
    return df_perf

# %%
log_reg_train = model_performance_classification(log_reg, x_train_sd, y_train)
log_reg_train
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.690871  0.690871   0.845537  0.712462

# %%
log_reg_val = model_performance_classification(log_reg, x_val_sd, y_val)
log_reg_val
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.692854  0.692854   0.846494  0.714829

# %% [markdown]
# Given a new data similar to the one used to train this model, the model will approximately 69% of the time correctly predict the income of an individual. However, it should be noted that the data used in building the model is imbalance and can produce an inaccurate result.

# %% [markdown]
# ### **Model Improvement strategy**
#
# Focus on Accuracy

# %%
log_reg2_train = model_performance_classification(log_reg, x_train_sd, y_train, threshold =0.9)
log_reg2_train
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.833982  0.833982   0.825724  0.827397

# %%
log_reg2_val = model_performance_classification(log_reg, x_val_sd, y_val, threshold =0.9)
log_reg2_val
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.839032  0.839032   0.830908  0.832267

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=0)

# %%
X_sm, y_sm = sm.fit_resample(X, y_new)

# %%
Counter(y_sm)
# Out:
# Counter({0: 24698, 1: 24698})

# %%
# split the data
x_temp, x_test_sm, y_temp, y_test_sm = train_test_split(X_sm, y_sm, test_size = 0.2, 
                                                  random_state = 0,)
x_train_sm, x_val_sm, y_train_sm, y_val_sm = train_test_split(x_temp, y_temp, test_size = 0.2, 
                                                  random_state = 0)

# %%
# Normalize the data using MinMaxScaler

x_train_sm_sd = scaler.fit_transform(x_train_sm)
x_val_sm_sd = scaler.transform(x_val_sm)
x_test_sm_sd = scaler.transform(x_test_sm)

# %%
log_reg3 = LogisticRegression(random_state = 0, max_iter=1000)

log_reg3.fit(x_train_sm_sd, y_train_sm)
# Out:
# LogisticRegression(max_iter=1000, random_state=0)

# %%
log_reg3_train = model_performance_classification(log_reg3, x_train_sm_sd, y_train_sm)
log_reg3_train
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.881469  0.881469   0.881834  0.881437

# %%
log_reg3_val = model_performance_classification(log_reg3, x_val_sm_sd, y_val_sm)
log_reg3_val
# Out:
#    Accuracy    Recall  Precision  F1-score
# 0  0.880693  0.880693   0.881717  0.880691

# %% [markdown]
# The accuracy improved to 88% from 69%

# %% [markdown]
# ### **Build KNN Model**

# %%
from sklearn.neighbors import KNeighborsClassifier

#import warnings filter
from warnings import simplefilter
#ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

# %%
# Create an instance of the KNN Model

knn = KNeighborsClassifier()

#Train the model
knn.fit(x_train_sd, y_train)
# Out:
# KNeighborsClassifier()

# %%
  # training accuracy
  acc_train = knn.score(x_train_sd, y_train)
  acc_val = knn.score(x_val_sd, y_val)
  acc_test = knn.score(x_test_sd, y_test)
  print(acc_train)
  print(acc_val)
  print(acc_test)
# Out:
# 0.8706718532392066
# 0.8203995389934691
# 0.8191456668715427

# %%
# Recall

rec_train =recall_score(y_train, pred_train)
rec_test =recall_score(y_test, pred_test)

print(rec_train)
print(rec_test)
# Out:
# 0.6912057302029447
# 0.5752551020408163

# %% [markdown]
# Out of the people in training data, our model was only able to predict 69% correctly

# %% [markdown]
# ### **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dec_tree = DecisionTreeClassifier(random_state=0)
dec_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
pred_train_dec = dec_tree.predict(x_train)
pred_test_dec = dec_tree.predict(x_test)

acc_train_dec = accuracy_score(y_train, pred_train_dec)
acc_test_dec = accuracy_score(y_test, pred_test_dec)

acc_train_dec
acc_test_dec
# Out:
# 0.7753534111862324

# %%
rec_train_dec = recall_score(y_train, pred_train_dec)
rec_test_dec = recall_score(y_test, pred_test_dec)

print(rec_train_dec)
print(rec_test_dec)
# Out:
# 0.9998010346199762
# 0.5427295918367347

# %% [markdown]
# This decision tree model is overfitting because it is performing worse on the test while the training shows almost perfect model
